# %%
#%run ../Getting_data/Getting_Data.ipynb

# %%
import datetime as dt
from datetime import date, datetime, timedelta
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [50, 15]
from pandas_profiling import ProfileReport

# %%
def plot_year_x(year,df,column):
    """
    With this function we will plot the time series of the year that we indicate.
    """
    # We create the dataframe to plot
    plot=df[df['datetime'].dt.year==year][[column,'datetime']]
    # We plot the dataframe
    sns.lineplot(x='datetime',y=column,data=plot)

def plot_all_years(df,column,resampling='D'):
    """
    With this function we will plot all the years, resampled by the period we indicate. The values shown will be the 
    mean of the period
    """
    # We create the dataframe to plot
    df_aux=df.set_index('datetime')[column].resample(resampling).mean()
    # We plot the dataframe
    sns.lineplot(x=df_aux.index,y=df_aux)

# %%
df = pd.read_csv('TFM_dataframe.csv',parse_dates=['datetime','datetime_utc','tz_time'])

# %% [markdown]
# ### Time series index

# %%
df = df.set_index('datetime')

# %% [markdown]
# ### Calculations based on other columns

# %% [markdown]
# It may be useful the use of the weekday

# %%
df['Weekday']=df.index.strftime('%A')
df['Hour']=df.index.hour

# %% [markdown]
# ### Fill NaN values

# %%
df[['Red_Electrica','IBEX35']]=df[['Red_Electrica','IBEX35']].ffill()

# %%
df.drop(['hour','quarter','Consumer_price_index', 'Time_required_to_get_electricity_(days)',
       'Inflation,consumer_prices_(annual_%)','Employment_in_industry_(%_of_total_employment)','geo_id','geo_name',
       'PIB_Trimestral', 'Var_Trim_PIB_(%)', 'Var_anual_PIB_Trim_(%)','datetime_utc','tz_time'],axis=1,inplace=True)

# %% [markdown]
# We may interpolate for those values missing for the market spot price:

# %%
df['Precio_mercado_SPOT_Intradiario_Sesion_1']=df['Precio_mercado_SPOT_Intradiario_Sesion_1'].interpolate(method='linear', limit_area='inside')
df['Precio_mercado_SPOT_Intradiario_Sesion_2']=df['Precio_mercado_SPOT_Intradiario_Sesion_2'].interpolate(method='linear', limit_area='inside')

# %% [markdown]
# For the temperature, the same assumpation will be considered:

# %%
df['Temperature']=df['Temperature'].interpolate(method='linear', limit_area='inside')

# %% [markdown]
# We may consider that if the programmed generation of power is null it may be because it is considered 0:

# %%
df[df.columns[pd.Series(df.columns).str.contains('Correccion|Generacion')]]=df[df.columns[pd.Series(df.columns).str.contains('Correccion|Generacion')]].fillna(0)

# %% [markdown]
# If we want to consider the effect of the date, we need to create a column in which we will put the day, another one for the month and the last one for the year.

# %% [markdown]
# Let's merge all the columns for the generation of power:

# %%
idx = df.columns.str.startswith('Generacion')
df['Generacion'] = df.iloc[:,idx].sum(axis=1)

# %%
idx = df.columns.str.startswith('Demanda')
df['Demanda'] = df.iloc[:,idx].sum(axis=1)

# %%
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col1 {
#             background-color:  #f59f80;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col2 {
#             background-color:  #f7b79b;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col3 {
#             background-color:  #f7b99e;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col4 {
#             background-color:  #f7bca1;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col5 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col6 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col7 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col8 {
#             background-color:  #dedcdb;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col9 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col10 {
#             background-color:  #efcfbf;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col11 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col12 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col13 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col14 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col15 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col16 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col17 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col18 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col19 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col20 {
#             background-color:  #efcfbf;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col21 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col22 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col23 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col24 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col25 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col26 {
#             background-color:  #edd2c3;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col27 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col28 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col29 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col30 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col31 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col32 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col33 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col34 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col35 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col36 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col37 {
#             background-color:  #f7a889;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row0_col38 {
#             background-color:  #f5a081;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row1_col0 {
#             background-color:  #f7aa8c;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row1_col2 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row1_col3 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row1_col4 {
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row1_col5 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row1_col6 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row1_col7 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row1_col8 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row1_col9 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row1_col10 {
#             background-color:  #f7b396;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row1_col11 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row1_col12 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row1_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row1_col14 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row1_col15 {
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row1_col16 {
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row1_col17 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row1_col18 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row1_col19 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_6b8eb578_da57_11ea_9dfb_616188102011row1_col20 {
#             background-color:  #

# %%
y_corr = df.corr()['Termino_de_facturacion_de_energia_activa_del_PVPC_eficiencia_2_periodos_(DHA)']
y_corr[(y_corr>0.3)|(y_corr<-0.3)]
# Out:
# Termino_de_facturacion_de_energia_activa_del_PVPC_eficiencia_2_periodos_(DHA)    1.000000
# Demanda_programada_P48_total                                                     0.570685
# Precio_mercado_SPOT_Diario                                                       0.545534
# Precio_mercado_SPOT_Intradiario_Sesion_1                                         0.535962
# Precio_mercado_SPOT_Intradiario_Sesion_2                                         0.529202
# Generacion_programada_P48_Consumo_bombeo                                         0.412708
# Generacion_programada_P48_Enlace_Baleares                                       -0.452440
# Generacion_programada_P48_Gas_Natural_Cogeneracion                               0.327345
# Generacion_programada_P48_Hulla_antracita                                        0.305893
# Generacion_programada_P48_Hulla_sub-bituminosa                                   0.348492
# Generacion_programada_P48_Solar_termica                                          0.355835
# Hour                                                                             0.486609
# Generacion                                                                       0.551224
# Demanda                                                                          0.569481
# Name: Termino_de_facturacion_de_energia_activa_del_PVPC_eficiencia_2_periodos_(DHA), dtype: float64

# %%
idx = df.columns.str.startswith('Generacion_')
df['Generacion_corr'] = df.iloc[:,idx].sum(axis=1)

# %% [markdown]
# ### Statistics

# %%
df.describe()
# Out:
#        Termino_de_facturacion_de_energia_activa_del_PVPC_eficiencia_2_periodos_(DHA)  \
# count                                       55726.000000
# mean                                           91.820804
# std                                            39.051148
# min                                            10.000000
# 25%                                            60.500000
# 50%                                            78.565000
# 75%                                           130.490000
# max                                           221.370000
#
#        Demanda_programada_P48_total  Precio_mercado_SPOT_Diario  \
# count                  55726.000000                55726.000000
# mean                   28286.150759                   47.347393
# std                     4669.081255                   14.868586
# min                    16428.400000                    0.030000
# 25%                    24384.125000                   38.830000
# 50%                    28427.950000                   48.400000
# 75%                    31862.025000                   57.890000
# max                    41297.900000                  101.990000
#
#        Precio_mercado_SPOT_Intradiario_Sesion_1  \
# count                               55726.00000
# mean                                   47.05100
# std                                    14.96884
# min                                     0.00000
# 25%                                    38.50000
# 50%                                    48.00000
# 75%                                    57.51000
# max                                   102.49000
#
#        Precio_mercado_SPOT_Intradiario_Sesion_2  \
# count                              55726.000000
# mean                                  47.028324
# std                                   14.992554
# min                                    0.000000
# 25%                                   38.570000
# 50%                                   48.000000
# 75%                                   57.330000
# max                                  103.610000
#
#        Demanda_programada_P48_Correccion_eolica  \
# count                              55726.000000
# mean                                 -18.574814
# std                                  462.319655
# min                                -3800.000000
# 25%                                 -300.000000
# 50%                                    0.000000
# 75%                                  200.000000
# max                                 3930.000000
#
#        Demanda_programada_P48_Correccion_solar  \
# count                             55726.000000
# mean                                -43.834072
# std                                 234.958484
# min                               -2600.000000
# 25%                                -100.000000
# 50%                                   0.000000
# 75%                                   0.000000
# max                                1800.000000
#
#        Generacion_programada_P48_Biogas  Generacion_programada_P48_Biomasa  \
# count                      55726.000000                       55726.000000
# mean                          65.569578                         394.012493
# std                           40.557815                         107.375300
# min                            0.000000                         141.200000
# 25%                           11.300000                         324.600000
# 50%                           87.600000                         357.000000
# 75%                           93.400000                         486.200000
# max                          150.200000                         661.400000
#
#        Generacion_programada_P48_Ciclo_combinado  ...         month  \
# count                               55726.000000  ...  55726.000000
# mean                                 3638.476677  ...      6.473675
# std                                  2497.072172  ...      3.369706
# min                                   307.000000  ...      1.000000
# 25%                                  1855.825000  ...      4.000000
# 50%                                  2797.800000  ...      6.000000
# 75%                                  4679.375000  ...      9.000000
# max                                 16938.700000  ...     12.000000
#
#                year      holidays  Red_Electrica        IBEX35   Temperature  \
# count  55726.000000  55726.000000   55726.000000  55726.000000  55636.000000
# mean    2016.929692      0.021534      13.403153   9609.744344     15.890354
# std        1.868088      0.145157       3.660785   1062.329950      6.406935
# min     2014.000000      0.000000       5.665498   6107.200195     -0.150406
# 25%     2015.000000      0.000000      10.076359   8993.000000     10.835849
# 50%     2017.000000      0.000000      14.925926   9622.700195     15.587814
# 75%     2019.000000      0.000000      16.402422  10377.189453     20.662215
# max     2020.000000      1.000000      18.729048  11866.388672     34.253240
#
#                Hour    Generacion       Demanda  Generacion_corr
# count  55726.000000  55726.000000  55726.000000     55726.000000
# mean      11.499605  27714.980533  28223.741873     27714.980533
# std        6.922059   4773.761445   4605.842316      4773.761445
# min        0.000000  14344.300000  16238.000000     14344.300000
# 25%        5.250000  23915.100000  24388.100000     23915.100000
# 50%       11.000000  27583.300000  28306.750000     27583.300000
# 75%       17.000000  31294.025000  31727.400000     31294.025000
# max       23.000000  42736.400000  41366.600000     42736.400000
#
# [8 rows x 40 columns]

# %%
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# HBox(children=(FloatProgress(value=0.0, description='variables', max=42.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='correlations', max=6.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='interactions [continuous]', max=1521.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=0.0, description='table', max=1.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='missing', max=3.0, style=ProgressStyle(description_width=…
# HBox(children=(FloatProgress(value=0.0, description='warnings', max=3.0, style=ProgressStyle(description_width…
# HBox(children=(FloatProgress(value=0.0, description='package', max=1.0, style=ProgressStyle(description_width=…
# HBox(children=(FloatProgress(value=0.0, description='build report structure', max=1.0, style=ProgressStyle(des…

# %%
plt.rcParams['figure.figsize'] = [12, 12]
sns.heatmap(df.drop('Weekday',axis=1).corr(),cmap='RdBu',center=0)

# %%
sns.clustermap(df.drop('Weekday',axis=1).corr(),cmap='RdBu',center=0)

# %%
df.to_csv('../Models/final_dataframe.csv')
