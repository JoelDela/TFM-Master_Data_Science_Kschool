# %%
# %run ../Getting_data/Getting_Data.ipynb
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54454 entries, 0 to 54453
# Data columns (total 49 columns):
# Termino_de_facturacion_de_energia_activa_del_PVPC_eficiencia_2_periodos_(DHA)    54454 non-null float64
# datetime                                                                         54454 non-null datetime64[ns, UTC]
# datetime_utc                                                                     54454 non-null datetime64[ns, UTC]
# tz_time                                                                          54454 non-null datetime64[ns, UTC]
# geo_id                                                                           54454 non-null int64
# geo_name                                                                         54454 non-null object
# Demanda_programada_P48_total                                                     54454 non-null float64
# Precio_mercado_SPOT_Diario                                                       54454 non-null float64
# Precio_mercado_SPOT_Intradiario_Sesion_1                                         54430 non-null float64
# Precio_mercado_SPOT_Intradiario_Sesion_2                                         54453 non-null float64
# Demanda_programada_P48_Correccion_eolica                                         46594 non-null float64
# Demanda_programada_P48_Correccion_solar                                          22692 non-null float64
# Generacion_programada_P48_Biogas                                                 44232 non-null float64
# Generacion_programada_P48_Biomasa                                                54454 non-null float64
# Generacion_programada_P48_Ciclo_combinado                                        54454 non-null float64
# Generacion_programada_P48_Consumo_bombeo                                         30310 non-null float64
# Generacion_programada_P48_Derivados_del_petroleo_o_carbon                        39426 non-null float64
# Generacion_programada_P48_Energia_residual                                       38857 non-null float64
# Generacion_programada_P48_Enlace_Baleares                                        54302 non-null float64
# Generacion_programada_P48_Eolica_terrestre                                       54454 non-null float64
# Generacion_programada_P48_Gas_Natural                                            16084 non-null float64
# Generacion_programada_P48_Gas_Natural_Cogeneracion                               54454 non-null float64
# Generacion_programada_P48_Hidraulica_UGH                                         54454 non-null float64
# Generacion_programada_P48_Hidraulica_no_UGH                                      54454 non-null float64
# Generacion_programada_P48_Hulla_antracita                                        54054 non-null float64
# Generacion_programada_P48_Hulla_sub-bituminosa                                   52391 non-null float64
# Generacion_programada_P48_Nuclear                                                54454 non-null float64
# Generacion_programada_P48_Oceano_y_geotermica                                    21372 non-null float64
# Generacion_programada_P48_Residuos_domesticos_y_similares                        46439 non-null float64
# Generacion_programada_P48_Residuos_varios                                        39086 non-null float64
# Generacion_programada_P48_Solar_fotovoltaica                                     39507 non-null float64
# Generacion_programada_P48_Solar_termica                                          48478 non-null float64
# Generacion_programada_P48_Subproductos_mineria                                   32346 non-null float64
# Generacion_programada_P48_Turbinacion_bombeo                                     33093 non-null float64
# day                                                                              54454 non-null int64
# month                                                                            54454 non-null int64
# year                                                                             54454 non-null int64
# hour                                                                             54454 non-null int64
# quarter                                                                          54454 non-null int64
# Consumer_price_index                                                             50424 non-null float64
# Time_required_to_get_electricity_(days)                                          50424 non-null float64
# Inflation,consumer_prices_(annual_%)                                             50424 non-null float64
# Employment_in_industry_(%_of_total_employment)                                   50424 non-null float64
# holidays                                                                         54454 non-null float64
# PIB_Trimestral                                                                   52608 non-null object
# Var_Trim_PIB_(%)                                                                 52608 non-null object
# Var_anual_PIB_Trim_(%)                                                           52608 non-null object
# Red_Electrica                                                                    1587 non-null float64
# IBEX35                                                                           1585 non-null float64
# dtypes: datetime64[ns, UTC](3), float64(36), int64(6), object(4)
# memory usage: 20.8+ MB

# %%
import datetime as dt
from datetime import date, datetime, timedelta
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [50, 15]
from pandas_profiling import ProfileReport

# %%
def plot_year_x(year,df,column):
    """
    With this function we will plot the time series of the year that we indicate.
    """
    # We create the dataframe to plot
    plot=df[df['datetime'].dt.year==year][[column,'datetime']]
    # We plot the dataframe
    sns.lineplot(x='datetime',y=column,data=plot)

def plot_all_years(df,column,resampling='D'):
    """
    With this function we will plot all the years, resampled by the period we indicate. The values shown will be the 
    mean of the period
    """
    # We create the dataframe to plot
    df_aux=df.set_index('datetime')[column].resample(resampling).mean()
    # We plot the dataframe
    sns.lineplot(x=df_aux.index,y=df_aux)

# %%
df = pd.read_csv('TFM_dataframe.csv',parse_dates=['datetime','datetime_utc','tz_time'])

# %% [markdown]
# ### Time series index

# %%
df = df.set_index('datetime')

# %% [markdown]
# ### Calculations based on other columns

# %% [markdown]
# It may be useful the use of the weekday

# %%
df['Weekday']=df.index.strftime('%A')
df['Hour']=df.index.hour

# %% [markdown]
# ### Fill NaN values

# %%
df[['Red_Electrica','IBEX35']]=df[['Red_Electrica','IBEX35']].ffill()

# %%
df.drop(['hour','quarter','Consumer_price_index', 'Time_required_to_get_electricity_(days)',
       'Inflation,consumer_prices_(annual_%)','Employment_in_industry_(%_of_total_employment)','geo_id','geo_name',
       'PIB_Trimestral', 'Var_Trim_PIB_(%)', 'Var_anual_PIB_Trim_(%)','datetime_utc','tz_time'],axis=1,inplace=True)

# %% [markdown]
# We may interpolate for those values missing for the market spot price:

# %%
df['Precio_mercado_SPOT_Intradiario_Sesion_1']=df['Precio_mercado_SPOT_Intradiario_Sesion_1'].interpolate(method='linear', limit_area='inside')
df['Precio_mercado_SPOT_Intradiario_Sesion_2']=df['Precio_mercado_SPOT_Intradiario_Sesion_2'].interpolate(method='linear', limit_area='inside')

# %% [markdown]
# We may consider that if the programmed generation of power is null it may be because it is considered 0:

# %%
df[df.columns[pd.Series(df.columns).str.contains('Correccion|Generacion')]]=df[df.columns[pd.Series(df.columns).str.contains('Correccion|Generacion')]].fillna(0)

# %% [markdown]
# If we want to consider the effect of the date, we need to create a column in which we will put the day, another one for the month and the last one for the year.

# %% [markdown]
# Let's merge all the columns for the generation of power:

# %%
idx = df.columns.str.startswith('Generacion')
df['Generacion'] = df.iloc[:,idx].sum(axis=1)

# %%
idx = df.columns.str.startswith('Demanda')
df['Demanda'] = df.iloc[:,idx].sum(axis=1)

# %% [markdown]
# ### Statistics

# %%
df.describe()
# Out:
#        Termino_de_facturacion_de_energia_activa_del_PVPC_eficiencia_2_periodos_(DHA)  \
# count                                       54454.000000
# mean                                           92.264796
# std                                            39.056999
# min                                            10.000000
# 25%                                            60.990000
# 50%                                            78.820000
# 75%                                           131.030000
# max                                           221.370000
#
#        Demanda_programada_P48_total  Precio_mercado_SPOT_Diario  \
# count                  54454.000000                54454.000000
# mean                   28274.804681                   47.645704
# std                     4675.215643                   14.887291
# min                    16428.400000                    0.030000
# 25%                    24366.325000                   39.420000
# 50%                    28421.000000                   48.820000
# 75%                    31849.450000                   58.087500
# max                    41297.900000                  101.990000
#
#        Precio_mercado_SPOT_Intradiario_Sesion_1  \
# count                              54454.000000
# mean                                  47.341215
# std                                   14.994888
# min                                    0.000000
# 25%                                   39.040000
# 50%                                   48.490000
# 75%                                   57.820000
# max                                  102.490000
#
#        Precio_mercado_SPOT_Intradiario_Sesion_2  \
# count                              54454.000000
# mean                                  47.317518
# std                                   15.019109
# min                                    0.000000
# 25%                                   39.100000
# 50%                                   48.340000
# 75%                                   57.620000
# max                                  103.610000
#
#        Demanda_programada_P48_Correccion_eolica  \
# count                              54454.000000
# mean                                 -19.243090
# std                                  464.274961
# min                                -3800.000000
# 25%                                 -300.000000
# 50%                                    0.000000
# 75%                                  200.000000
# max                                 3930.000000
#
#        Demanda_programada_P48_Correccion_solar  \
# count                             54454.000000
# mean                                -46.390311
# std                                 234.634058
# min                               -2600.000000
# 25%                                -100.000000
# 50%                                   0.000000
# 75%                                   0.000000
# max                                1800.000000
#
#        Generacion_programada_P48_Biogas  Generacion_programada_P48_Biomasa  \
# count                      54454.000000                       54454.000000
# mean                          64.896705                         393.865351
# std                           40.782189                         108.387248
# min                            0.000000                         141.200000
# 25%                           11.100000                         323.800000
# 50%                           87.300000                         356.200000
# 75%                           93.200000                         490.800000
# max                          150.200000                         661.400000
#
#        Generacion_programada_P48_Ciclo_combinado  ...  \
# count                               54454.000000  ...
# mean                                 3551.653085  ...
# std                                  2443.451037  ...
# min                                   307.000000  ...
# 25%                                  1838.000000  ...
# 50%                                  2745.450000  ...
# 75%                                  4471.225000  ...
# max                                 16938.700000  ...
#
#        Generacion_programada_P48_Turbinacion_bombeo           day  \
# count                                  54454.000000  54454.000000
# mean                                     249.563106     15.682227
# std                                      389.209949      8.800055
# min                                        0.000000      1.000000
# 25%                                        0.000000      8.000000
# 50%                                       60.100000     16.000000
# 75%                                      341.000000     23.000000
# max                                     2831.300000     31.000000
#
#               month          year      holidays  Red_Electrica        IBEX35  \
# count  54454.000000  54454.000000  54454.000000   54454.000000  54454.000000
# mean       6.464098   2016.857972      0.022037      13.952407   9664.200751
# std        3.406871      1.829186      0.146805       3.839828   1012.025109
# min        1.000000   2014.000000      0.000000       5.931983   6107.200195
# 25%        4.000000   2015.000000      0.000000      10.397486   9059.291016
# 50%        6.000000   2017.000000      0.000000      15.537788   9661.799805
# 75%        9.000000   2018.000000      0.000000      17.097551  10394.189453
# max       12.000000   2020.000000      1.000000      19.610001  11866.388672
#
#                Hour    Generacion       Demanda
# count  54454.000000  54454.000000  54454.000000
# mean      11.499596  27689.461112  28209.171280
# std        6.922056   4766.651701   4611.213401
# min        0.000000  14344.300000  16238.000000
# 25%        5.250000  23893.900000  24366.000000
# 50%       11.000000  27555.400000  28292.650000
# 75%       17.000000  31257.400000  31710.275000
# max       23.000000  42736.400000  41366.600000
#
# [8 rows x 38 columns]

# %%
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# HBox(children=(FloatProgress(value=0.0, description='variables', max=40.0, style=ProgressStyle(description_wid…
# /home/joeldela/anaconda3/lib/python3.7/site-packages/astropy/stats/bayesian_blocks.py:429: RuntimeWarning: divide by zero encountered in log
#   return N_k * (np.log(N_k) - np.log(T_k))
# HBox(children=(FloatProgress(value=0.0, description='correlations', max=6.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='interactions [continuous]', max=1369.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=0.0, description='table', max=1.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='missing', max=2.0, style=ProgressStyle(description_width=…
# HBox(children=(FloatProgress(value=0.0, description='warnings', max=3.0, style=ProgressStyle(description_width…
# HBox(children=(FloatProgress(value=0.0, description='package', max=1.0, style=ProgressStyle(description_width=…
# HBox(children=(FloatProgress(value=0.0, description='build report structure', max=1.0, style=ProgressStyle(des…

# %%
plt.rcParams['figure.figsize'] = [12, 12]
sns.heatmap(df.drop('Weekday',axis=1).corr(),cmap='RdBu',center=0)

# %%
sns.clustermap(df.drop('Weekday',axis=1).corr(),cmap='RdBu',center=0)

# %%
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col1 {
#             background-color:  #f59f80;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col2 {
#             background-color:  #f7b79b;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col3 {
#             background-color:  #f7b99e;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col4 {
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col5 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col6 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col7 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col8 {
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col9 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col10 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col11 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col12 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col13 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col14 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col15 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col16 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col17 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col18 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col19 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col20 {
#             background-color:  #edd1c2;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col21 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col22 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col23 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col24 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col25 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col26 {
#             background-color:  #edd1c2;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col27 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col28 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col29 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col30 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col31 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col32 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col33 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col34 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col35 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col36 {
#             background-color:  #f7a688;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow0_col37 {
#             background-color:  #f59f80;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow1_col0 {
#             background-color:  #f7a98b;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow1_col2 {
#             background-color:  #f7bca1;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow1_col3 {
#             background-color:  #f6bda2;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow1_col4 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow1_col5 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow1_col6 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow1_col7 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow1_col8 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow1_col9 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow1_col10 {
#             background-color:  #f7b396;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow1_col11 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow1_col12 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow1_col13 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow1_col14 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow1_col15 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow1_col16 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow1_col17 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow1_col18 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow1_col19 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow1_col20 {
#             background-color:  #edd2c3;
#             color:  #000000;
#         }    #T_55294240_c2dc_11ea_b068_935ed1b2805erow1_col21 {
#             background-color:  #

# %%
df.to_csv('../Models/final_dataframe.csv')
